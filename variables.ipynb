# %%
phoneNumber = 12345
print(phoneNumber)
# Out:
# 12345

# %%
name= "Hasib"
print(name)
# Out:
# Hasib

# %%
name= "hasib"
age = 27
height = 5.10
isPassed = True

print(type(name), type(age), type(height), type(isPassed))
# Out:
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>

# %%
name = input("What is your name? ")
print(name)
# Out:
# Hasib

# %%
age = input("What is your age") #taking input as a string
age = int(age) #type casting as int
print(age, type(age))
# Out:
# 20 <class 'int'>

# %%
height = float(input("What is your height? "))
print(height, type(height))
# Out:
# 20.0 <class 'float'>

# %%
x = 10; y = 20; z = 30;

result = (x < y) or (x > z)

print(result);
# Out:
# True

# %% [markdown]
# ## Precedence and Associativity

# %%
eq = 10 + 10 / 2 - 5 * 2

eq
# Out:
# 5.0

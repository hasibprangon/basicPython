# %%
phoneNumber = 12345
print(phoneNumber)
# Out:
# 12345

# %%
name= "Hasib"
print(name)
# Out:
# Hasib

# %%
name= "hasib"
age = 27
height = 5.10
isPassed = True

print(type(name), type(age), type(height), type(isPassed))
# Out:
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>
